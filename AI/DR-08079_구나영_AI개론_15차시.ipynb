# %% [markdown]
# <a href="https://colab.research.google.com/github/kny1209/test2/blob/main/AI/DR-08079_%EA%B5%AC%EB%82%98%EC%98%81_AI%EA%B0%9C%EB%A1%A0_15%EC%B0%A8%EC%8B%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [문항 1] 주관식 PyTorch의 ImageFolder를 사용하여 이미지 데이터를 로드하려고 합니다. 이때 데이터셋 디렉터리(root/) 내부는 어떤 구조로 정리되어 있어야 합니까? 하위 폴더의 이름은 무엇을 의미하게 되는지 서술하시오.

# %% [markdown]
# [답안 작성란]
#
# 데이터셋의 루트 디렉터리 아래에 각 클래스(레이블)이름으로 된 하위 폴더를 만들고 해당 폴더 안에 그 클래스에 해당하는 이미지 파일들을 저장해야 한다. (트리구조)
#
# 이때 하위 폴더의 이름이 자동으로 데이터의 레이블로 인식된다

# %% [markdown]
# [문항 2] 주관식 강의에서 다룬 '시베리안 허스키 vs 늑대' 분류 사례처럼 훈련 데이터가 매우 적은 경우(예: 40장), 모델의 성능을 높이고 과적합(Overfitting)을 방지하기 위해 적용할 수 있는 주요 기법 두 가지를 설명하시오. (힌트: 모델 학습 방식과 데이터 처리 방식 측면에서 각각 하나씩)

# %% [markdown]
# [답안 작성란]
#
# 전이 학습 (Transfer Learning) : 대량의 데이터로 미리 학습된 모델의 가중치를 가져와, 부족한 데이터로 재학습(Fine-tunnung)하거나 특징 추출기로 사용하여 학습 효율을 높인다.
#
# 데이터 증강 (Data Augmentation) : 훈련 이미지를 회전, 자르기, 뒤집기, 지우기등을 통해 인위적으로 변형하여 데이터의 다양성을 늘리고 과적합을 방지한다.

# %% [markdown]
# [문항 3] 코드 구현 검증(Validation) 데이터셋을 위한 전처리 코드를 작성하시오.
#
# 요구사항:
#
# 이미지 크기를 256으로 변경 (Resize)
#
# 중앙을 224x224 크기로 자름 (CenterCrop)
#
# 텐서(Tensor) 형태로 변환
#
# 정규화 (평균: 0.5, 표준편차: 0.5) 적용

# %%
import torchvision.transforms as transforms

# 검증 데이터용 transform 정의
test_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),     # 검증 데이터는 이미지를 왜곡하지 않고 중앙만 잘라내어 평가하는 것이 일반적

    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

# %% [markdown]
# [문항 4] 코드 구현 훈련(Train) 데이터셋을 위한 전처리 코드를 작성하시오. 데이터 부족 문제를 완화하기 위해 데이터 증강(Data Augmentation) 기법을 포함해야 합니다.
#
# 요구사항:
#
# 무작위 크기 및 비율로 자른 후 224로 크기 변경 (RandomResizedCrop)
#
# 무작위로 수평 뒤집기 (RandomHorizontalFlip)
#
# 텐서(Tensor) 형태로 변환
#
# 정규화 (평균: 0.5, 표준편차: 0.5) 적용
#
# 무작위로 영역 지우기 (RandomErasing) - (확률 0.5, scale 등은 강의 코드 참조 혹은 기본값)

# %%
# 훈련 데이터용 transform 정의 (데이터 증강 적용)
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),

    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5)),

    transforms.RandomErasing(p=0.5,scale=(0.02, 0.33), ratio=(0.3, 0.3), value=0, inplace=False)
])

# %% [markdown]
# [문항 5] 코드 구현 위에서 정의한 transform을 사용하여 ImageFolder로 데이터셋을 불러오는 코드를 작성하시오.
#
# train_dir: 훈련 데이터 경로
#
# test_dir: 검증 데이터 경로

# %%
import torchvision.datasets as datasets
import os

# 경로 설정 (예시 경로)
data_dir = 'hymenoptera_data'
train_dir = os.path.join(data_dir, 'train')
test_dir = os.path.join(data_dir, 'val')

# ImageFolder를 이용한 데이터셋 정의
# ( 여기에 코드를 작성하시오 )
# train_data = datasets.ImageFolder(train_dir, transform = train_transform)
# test_data = datasets.ImageFolder(test_dir, transform = test_transform)

# %% [markdown]
# [문항 6] 코드 구현 불러온 데이터셋을 모델에 공급하기 위한 DataLoader를 정의하시오.
#
# 배치 사이즈(batch_size): 5
#
# 훈련용 로더: 데이터를 섞어서(shuffle=True) 로드
#
# 검증용 로더: 데이터를 섞지 않고(shuffle=False) 로드

# %%
from torch.utils.data import DataLoader

batch_size = 5

# 데이터 로더 정의
# ( 여기에 코드를 작성하시오 )
# train_loader = DataLoader(train_data, batch_size = batch_size, shuffle = True)
# test_loader = DataLoader(test_data, batch_size = batch_size, shuffle = False)
